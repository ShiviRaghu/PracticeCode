# %% [markdown]
# <a href="https://colab.research.google.com/github/ShiviRaghu/PracticeCode/blob/feature_branch/Class4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AGENDA
# 1. Operators
#   - Arithmatic
# 2. String methods
# 3. Control flow statements

# %%
a =12
b =13

print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
a**(1/2)
# Out:
# 25
# -1
# 156
# 0.9230769230769231
# 0
# 12
# 3.4641016151377544

# %% [markdown]
# ### String methods

# %% [markdown]
# if N characters or elements are there in a string then
#
# the index range will vary from 0 to N-1
# for example is "Sunny" N = 5
# index value is ranging from 0 to 4
#
# to index in reverse order the index  ranges from -1 to -N

# %%
s ="shivi"
print(s[0])    #index 01234   or      -5-4-3-2-1 from back side
print(s[-1])
#s[5]
print(s[-5])
# Out:
# s
# i
# s

# %% [markdown]
# ### String slicing/reverse string

# %%
##STRING SLICING

s ="shivi"
print(s[0:1])
print(s[0:-1])
print(s[1:3])
print(s[1:])
print(s[-5:-1])

s ="26/08/2023"
date = s[0:2]
month = s[3:5]
year =s[6:9]
print(f"todays month = {month}")
# Out:
# s
# shiv
# hi
# hivi
# shiv
# todays month = 08

# %%
##STRING SLICING

s ="shivi"
print(s[0:5:2] )  ###start:ending:step taking step of 1
print(s[0:5:3])
print(s[1: :2])
print(s[::1])
print(s[5::-1])
print(s[::-1])
# Out:
# sii
# sv
# hv
# shivi
# ivihs
# ivihs

# %%
s ="shivani raghuwanshi"
s[: :-1]
s[::-2]
# Out:
# 'isaugriais'

# %%
###string is palindrome

s = input("enter name to check ?  ")
srev = s[::-1]

if srev==s:
 print("name is palindrome")
else:
  print("not a palindrome")
# Out:
# enter name to check ?  radar
# name is palindrome

# %% [markdown]
# ### mutable string

# %%
#### replace s with h
s ="shivi"
s[0]="h"
s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-5867df3be4d3> in <cell line: 3>()
#       1 #### replace s with h
#       2 s ="shivi"
# ----> 3 s[0]="h"
#       4 s
#
# TypeError: 'str' object does not support item assignment

# %%
"h"+s[1:] ## concatinating
s   ###but not printing
s = "h" + s[1:]
s
# Out:
# 'hhivi'

# %%
s = s.replace("s","h")
s
s =s.replace("h","S")
s
# Out:
# 'hhivi'

# %%
name = "shivani raghuwanshi is good"
name = name.replace(" ","_")
name
# Out:
# 'shivani_raghuwanshi_is_good'

# %% [markdown]
# ### length

# %%
len(name)
len("shivi")
# Out:
# 5

# %%
####count and split

s ="shivi"
s.count("i")
s.count("u")

name ="a b c"
first , sec ,third = name.split(" ")
print(f"""
{first}
{sec}
{third}
""")


m ="shivi rahj jkjk"
u =m.split(" ")
u[0]
len (u)
# Out:
# a
# b
# c
# 3

# %%
#####cases---lower,upper------ ####join

name = input("enter name ")
print(f"{name.lower()}")
print(f"{name.upper()}")
print(f"{name.title()}")
print(f"{name.capitalize()}")
print(f"{name.swapcase()}")
# Out:
# enter name AHKJJK kjklk kjlSDSD kjlk
# ahkjjk kjklk kjlsdsd kjlk
# AHKJJK KJKLK KJLSDSD KJLK
# Ahkjjk Kjklk Kjlsdsd Kjlk
# Ahkjjk kjklk kjlsdsd kjlk
# ahkjjk KJKLK KJLsdsd KJLK

# %%
name ="gjhk jlk;l"
" ".join(name)
"sed".join(name)
# Out:
# 'gsedjsedhsedksed sedjsedlsedksed;sedl'

# %% [markdown]
# ### strip,join

# %%
name ="  sjjjk dgggg     "
name.strip(" ")
name.lstrip(" ")
name.rstrip(" ")

name ="@@@@@ jhkl nml @@@"
name.strip("@")
# Out:
# ' jhkl nml '

# %% [markdown]
# ### formatting

# %%
n ="sguhi"
n.center(10,"a")
n.center(2,"#")   ###not work for less than length
# Out:
# 'sguhi'

# %% [markdown]
# ### Checking string cases

# %%
name =" shibji "
name.isupper()
name.islower()
name.istitle()
####name.iscapitalize()
name.isspace()

x =" "
x.isspace()
# Out:
# True

# %%
y = input("enter any string")

if y.istitle():
  print(f"already in title case {y}")
elif y.isspace():
  print("wrong input provide correct input")
else :
 y = y.title()
 print(f"corrected in title case {y}")
# Out:
# enter any string
# wrong input provide correct input

# %%
num ="7980798567697809"
num.isdigit()


al ="sfsf"
al.isalpha();

# %%
num =input("input phone nnum ")

if num.isdigit and len(num)==10:
  print("you have entered correct number")
else:
  print("please enter correct number")

num.startswith("0")
num.endswith("9")
num[1:]
# Out:
# input phone nnum 89
# please enter correct number
# '9'

# %%
num ="+913456788999"

if num.isdigit and len(num)==13 and num.startswith("+91"):
  print("number is indian number")
else:
  print("please reenter number")
# Out:
# number is indian number

# %%
###alphanumeric

a ="abkjjkl123"
a ="12234"
a="    124lklk"
a ="afsdg13!@#$"
a.isalnum()    ### aplha or num or both
# Out:
# False
