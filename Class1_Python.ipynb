# %% [markdown]
# <a href="https://colab.research.google.com/github/ShiviRaghu/PracticeCode/blob/feature_branch/Class1_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Printing statement**

# %% [markdown]
# 1. print (" ") or print(' ')
# 2. " " or ' ' only 1 can be print,if many then last
# 3. multiLine ("""
# """)
# 4. " "
# print(" ")  # only print last line with print   / " " if its at the last
# 5.####comment

# %%
print("hello world")
print('hello')
print("revision")
print('single slash')
print("2nd revision")
print('ijhucfghjk')
# Out:
# hello world
# hello
# revision
# single slash
# 2nd revision
# ijhucfghjk

# %%
"abc"
"def"
"last line"
'last last line'
"laldkfkvkklkl"
'sdfhjkl'
# Out:
# 'sdfhjkl'

# %%
print("""abc
def""")

print("""
1st lline
2nd line

""")

#print(""
#abc
#def
#ghi
#"")


print("""
xdfcghjkl
fcvghjkl;
fcghjkl
""")

"""
"adcsc"
"""
# Out:
# abc
# def
#
# 1st lline
# 2nd line
#
#
#
# xdfcghjkl
# fcvghjkl;
# fcghjkl
# '\n"adcsc"\n'

# %%
 "morning"
 print("xcvbhnm")
 print("""
 sdfghjkl
 zsdfhjkl
 sdfkl
 """)
'modfghk'
"asdfghjkl;"
# Out:
# xcvbhnm
#
# sdfghjkl
# zsdfhjkl
# sdfkl
# 'asdfghjkl;'

# %%
"morning"
print("good")
"asdfghjko"
# Out:
# good
# 'asdfghjko'

# %% [markdown]
# # comment line
#
# 1. #
# 2. multiline comment """
# """ with **print at last otherwiise this will print**

# %%
"""
jij
kjkj
"""
# Out:
# '\njij\nkjkj\n'

# %%
 """
Say Hi
To the students
"""
print("hello")
# Out:
# hello

# %%
#hii
"""xcfgvhbjkl
xdfcghjkl
xcvb
"""
print("szhjkl")
# Out:
# szhjkl

# %%
#hiii
"""sgdfg
fgfggf
gfhgj
"""
"kjk"
# Out:
# 'kjk'

# %% [markdown]
# # Print in double quotes
#
# 1. (" 'xyz ' ")
# 2. (' "xyz" ')
# 3. (""" "xyz"! """)
# 4. (""" "xyz" """)
# 4. (""" \"xyz\" """)

# %%
 print("my name is 'xyz' ")
# Out:
# my name is 'xyz'

# %%
print(" ' i m cool ' ")
print(' " i m cool" ')
print(""" 'i m ok' """)
print(""" ""i  m ok"" """)
# Out:
#  ' i m cool '
#  " i m cool"
#  'i m ok'
#  ""i  m ok""

# %%
 print('my name is "shici" ')
# Out:
# my name is "shici"

# %%
 print("""my name is 'shici' """)
# Out:
# my name is 'shici'

# %%
 print("""my name is 'shici'! """)
# Out:
# my name is 'shici'!

# %%
 print("""my name is "shici"! """)
# Out:
# my name is "shici"!

# %%
 print("""my name is "shici" """)
# Out:
# my name is "shici"

# %%
 print("""my name is \'shici\' """)
# Out:
# my name is 'shici'

# %%
 print("my name is \"shici\" ")
# Out:
# my name is "shici"

# %% [markdown]
# # **calci**

# %%
1+2
# Out:
# 3

# %%
12*12
# Out:
# 144

# %%
12/123
# Out:
# 0.0975609756097561

# %%
print(12**2) ####    ** = power of n
print(2**8)

print(2**3)
# Out:
# 144
# 256
# 8

# %%
(-12)**3 ###negative power ##power of 3
# Out:
# -1728

# %%
124%12     #modulus ---remainder
# Out:
# 4

# %%
print(1234%12)
print("result")
# Out:
# 10
# result

# %%
1234%12
print("result")
# Out:
# result

# %% [markdown]
# #variables in python

# %%
x=10
y=20
print(x)
print(x+y)
# Out:
# 10
# 30

# %% [markdown]
# ## 1. variable name start with alphabets**

# %%
ten=10
tenn_num=122

# %% [markdown]
# ### 2. not contain sp chars @#$%^&*()! except_

# %%
ten* =10
# Out:
#   File "<ipython-input-47-8e602cc286fc>", line 1
#     ten* =10
#          ^
# SyntaxError: invalid syntax

# %%
ten(% =23)
# Out:
#   File "<ipython-input-48-248f1d482f0c>", line 1
#     ten(% =23)
#         ^
# SyntaxError: invalid syntax

# %%
ten/nu, =12
# Out:
#   File "<ipython-input-50-13fad490dd0a>", line 1
#     ten/nu, =12
#     ^
# SyntaxError: cannot assign to expression

# %% [markdown]
# ### 3.can cotain number but can't start with it

# %%
ten12 =123

# %%
12tehnkk =90
# Out:
#   File "<ipython-input-52-c692873611e6>", line 1
#     12tehnkk =90
#      ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# ## 4. not rule but should start with small letter in variable

# %%
Ten = 10

# %%
ten num =233
# Out:
#   File "<ipython-input-54-696a9a8029e7>", line 1
#     ten num =233
#         ^
# SyntaxError: invalid syntax

# %%
ten_num = 123

# %%
_num =10 #####hidden  ###not visible to end user (in black box)
print(_num)
# Out:
# 10

# %%
_ = 10 ######dummy variable
print(_)
# Out:
# 10

# %%
xyz =10;
print(xyz)
z_o = 1000;
z_o
# Out:
# 10
# 1000

# %% [markdown]
# # data types

# %% [markdown]
# ## integer

# %%
a =123
type(a)
# Out:
# int

# %%
a =9089009756789
type(a)
# Out:
# int

# %% [markdown]
# ## floats

# %%
p =12.789
type(p)
# Out:
# float

# %%
p=22/7
type(p)
# Out:
# float

# %%
p=2.00
type(p)
# Out:
# float

# %%
p =12/2
print(p)
type(p)
# Out:
# 6.0
# float

# %% [markdown]
# ## Complex number

# %%
a =1+2j
print(a)
b = 3.123+3j
b
# Out:
# (1+2j)
# (3.123+3j)

# %%
type(a)
# Out:
# complex

# %%
print(a.real)
b.real
# Out:
# 1.0
# 3.123

# %%
a.imag
b.imag
# Out:
# 3.0

# %%
"""
a ="sfdfd"
type(a)
"""

a ='sdfghjk'
print(type(a))
b='a'
type(b)
b1="sdfgvhbjn"
type(b1)
# Out:
# <class 'str'>
# str

# %% [markdown]
# ## dynamic typing  ---override value as well as data type

# %%
a =12
print(type(a))
a =12.2
print(type(a))
a ="shici"
type(a)
a
# Out:
# <class 'int'>
# <class 'float'>
# 'shici'

# %% [markdown]
# ## Strong Typing -- concat same data type or use   " " or ' '

# %%
"shivi"+01
# Out:
#   File "<ipython-input-24-542bbb28e8f6>", line 1
#     "shivi"+01
#             ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
"shivi"+"01"
# Out:
# 'shivi01'

# %%
'shivi' +'01'
# Out:
# 'shivi01'

# %%
'11233'+'23232'
# Out:
# '1123323232'

# %%
'123242' +"0.132432"
# Out:
# '1232420.132432'

# %%
name ="abha"
print("my name is " + name ) ##rarely used
zy =  10
print("number " + zy)
# Out:
# my name is abha
# number 10

# %%
name ="abjjkbha"
age = 123
print(f"my name is {name} and age is {age} ") ##mostly used ##f---fromatted string method
##print("my name is " + name  + "and age is " + age)
print ()
# Out:
# my name is abjjkbha and age is 123
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-a0fefd28b6a9> in <cell line: 4>()
#       2 age = 123
#       3 print(f"my name is {name} and age is {age} ") ##mostly used ##f---fromatted string method
# ----> 4 print("my name is " + name  + "and age is " + age)
#
# TypeError: can only concatenate str (not "int") to str

# %%
a ="shhic"
b =123;
print(f"a is {a} and b is {b}")
print(f"value of a is = {a} and value of b is = {b}")
# Out:
# a is shhic and b is 123
# value of a is = shhic and value of b is = 123

# %%
name ="abha"
age =789
print("my name is {} and age is {}".format(name,age)) ##old way
# Out:
# my name is abha and age is 789

# %%
a=121
b=1323
c=a+b
f"sum of a= {a} and b={b} is equal to {c}"
# Out:
# 'sum of a= 121 and b=1323 is equal to 1444'

# %%
a=123
b=145
c =a/b
print(f" division of {a} / {b} = {c}")
# Out:
#  division of 123 / 145 = 0.8482758620689655

# %%
a =123;
b =1324;
c =a+b;
print(f"sum of {a} + {b} = {c}")
# Out:
# sum of 123 + 1324 = 1447

# %% [markdown]
# ## boolean

# %%
x=113
b=678
c=x>b
type(c)
print(type(c))
# Out:
# <class 'bool'>

# %% [markdown]
# # Revision

# %%
print("my nam is shivi")
"shivi"
"sfdsgdg"
print('abxc')
print("""avc""")
#print(""""sfdsfgs"""")
print("""one
two
three""")
"adada"

#cvfgfgf
"""jkjl dfdsfd dfdgfd """
"xbcdf"

print("hi is an 'important' ")
print('hi is an "important" ')
print("""hi is an 'important' """)
print("""hi is an "important" """)
print("hi is an \"important\" ")

# %%
2+3
2*3
2**3
z = 13243
z_o =131
zds =12
_ =1324

# %%
a =123
type(a)
print(type(a))
a =12/6
print(type(a))
a =123+2.455j
print(type(a)); print(a)
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# (123+2.455j)

# %%
a =12
b=14
print (f"num 1 = {a} and num 2 is {b} and sum = {a+b}")

a,c,d,e = 1,543,3.454,"sfsdf"
print(type(a))
print(type(c))
print(type(e))
print(type(d))
a=b=c=d=120
a,a =10,12
a
# Out:
# num 1 = 12 and num 2 is 14 and sum = 26
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'float'>
# 12

# %%
print ="sdfsf"

del print
print("sdfd")

# %%
"""input("")
a = int(input("value of a = "))
b = int(input("value of b = "))
print (f"num 1 = {a} and num 2 is {b} and sum = {a+b}")"""

a1= "100"
type(a1)
a1 =int(a1)
type(a1)

a1= "100.10"
type(a1)
#a1 =int(a1)
type(a1)

a1= 100.10
type(a1)
a1 =int(a1)
type(a1)

a1= 100
type(a1)
a1 =float(a1)
type(a1)

a1= 100
type(a1)
a1 =bool(a1)
print(type(a1))
print(a1)

a1= "100"
type(a1)
a1 =bool(a1)
type(a1)
# Out:
# <class 'bool'>
# True
# bool
