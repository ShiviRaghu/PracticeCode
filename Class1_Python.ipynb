# %% [markdown]
# <a href="https://colab.research.google.com/github/ShiviRaghu/PracticeCode/blob/main/Class1_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Printing statement**

# %% [markdown]
# 1. print (" ")
# 2. " "  ###only 1 can be print,if many then last
# 3. multiLine ("""
# """)
# 4. " "
# print(" ")  # only print last line with print

# %%
print("hello everyone")
print("hi")
# Out:
# hello everyone
# hi

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
"good"
"hjkl"
# Out:
# 'hjkl'

# %%
print("good
evening
      india")
# Out:
#   File "<ipython-input-3-509bc44e9c92>", line 1
#     print("good
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
 print(""" good
 india
 morning
 shivani"""
 )
# Out:
#  good
# india
# morning
# shivani

# %%
 morning
 print("good")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-7193941c7b80> in <cell line: 1>()
# ----> 1 morning
#       2 print("good")
#
# NameError: name 'morning' is not defined

# %%
"morning"
print("good")
# Out:
# good

# %%
"morning"
# Out:
# 'morning'

# %%
"morninh"
print("ho")
# Out:
# ho

# %%
"morninh"
print("ho")
# Out:
# ho

# %% [markdown]
# # comment line
#
# 1. #
# 2. multiline """
# """ with print at last otherwiise this will print

# %%
"""
jij
kjkj
"""
# Out:
# '\njij\nkjkj\n'

# %%
 """
Say Hi
To the students
"""
print("hello")
# Out:
# hello

# %%
#hii

# %%
#hiii
"kjk"
# Out:
# 'kjk'

# %% [markdown]
# # Print in double quotes
#
# 1. (" 'xyz ' ")
# 2. (' "xyz" ')
# 3. (""" "xyz"! """)
# 4. (""" "xyz" """)
# 4. (""" \"xyz\" """)

# %%
 print("my name is 'shici' ")
# Out:
# my name is 'shici'

# %%
 print('my name is "shici" ')
# Out:
# my name is "shici"

# %%
 print("""my name is 'shici' """)
# Out:
# my name is 'shici'

# %%
 print("""my name is 'shici'! """)
# Out:
# my name is 'shici'!

# %%
 print("""my name is "shici"! """)
# Out:
# my name is "shici"!

# %%
 print("""my name is "shici" """)
# Out:
# my name is "shici"

# %%
 print("""my name is '\shici'\ """)
# Out:
# my name is '\shici'\

# %%
 print("my name is \"shici\" ")
# Out:
# my name is "shici"

# %% [markdown]
# # **calci**

# %%
1+2
# Out:
# 3

# %%
12*12
# Out:
# 144

# %%
12/123
# Out:
# 0.0975609756097561

# %%
12**2 ######power of 2
# Out:
# 144

# %%
(-12)**  ###negative power
# Out:
# -1728

# %%
124%12
# Out:
# 4

# %%
print(1234%12)
print("result")
# Out:
# 10
# result

# %%
1234%12
print("result")
# Out:
# result

# %% [markdown]
# #variables in python

# %%
x=10
y=20
print(x)
print(x+y)
# Out:
# 10
# 30

# %%
i

# %% [markdown]
# ## 1. variable name start with alphabets**

# %%
ten=10
tenn_num=122

# %% [markdown]
# ### 2. not contain sp chars @#$%^&*()! except_

# %%
ten* =10
# Out:
#   File "<ipython-input-47-8e602cc286fc>", line 1
#     ten* =10
#          ^
# SyntaxError: invalid syntax

# %%
ten(% =23)
# Out:
#   File "<ipython-input-48-248f1d482f0c>", line 1
#     ten(% =23)
#         ^
# SyntaxError: invalid syntax

# %%
ten/nu, =12
# Out:
#   File "<ipython-input-50-13fad490dd0a>", line 1
#     ten/nu, =12
#     ^
# SyntaxError: cannot assign to expression

# %% [markdown]
# ### 3.can cotain number but can't start with it

# %%
ten12 =123

# %%
12tehnkk =90
# Out:
#   File "<ipython-input-52-c692873611e6>", line 1
#     12tehnkk =90
#      ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# ## 4. not rule but should start with small letter in variable

# %%
Ten = 10

# %%
ten num =233
# Out:
#   File "<ipython-input-54-696a9a8029e7>", line 1
#     ten num =233
#         ^
# SyntaxError: invalid syntax

# %%
ten_num = 123

# %%
_num =10 #####hidden  ###not visible to end user (in black box)
print(_num)
# Out:
# 10

# %%
_ = 10 ######dummy variable
print(_)
# Out:
# 10

# %% [markdown]
# # data types

# %% [markdown]
# ## integer

# %%
a =123
type(a)
# Out:
# int

# %%
a =9089009756789
type(a)
# Out:
# int

# %% [markdown]
# ## floats

# %%
p =12.789
type(p)
# Out:
# float

# %%
p=22/7
type(p)
# Out:
# float

# %%
p=2.00
type(p)
# Out:
# float

# %%
p =12/2
p
type(p)
# Out:
# float

# %% [markdown]
# ## Complex number

# %%
a =1+2j
a
# Out:
# (1+2j)

# %%
type(a)
# Out:
# complex

# %%
a.real
# Out:
# 1.0

# %%
a.imag
# Out:
# 2.0

# %% [markdown]
# ## dynamic typing  ---override value as well as data type

# %%
a =12
type(a)
a =12.2
type(a)
a
a ="shici"
type(a)
a
# Out:
# 'shici'

# %% [markdown]
# ## Strong Typing -- concat same data type or use"" /''

# %%
"shivi"+01
# Out:
#   File "<ipython-input-24-542bbb28e8f6>", line 1
#     "shivi"+01
#             ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
"shivi"+"01"
# Out:
# 'shivi01'

# %%
'shivi' +'01'
# Out:
# 'shivi01'

# %%
'11233'+'23232'
# Out:
# '1123323232'

# %%
'123242' +"0.132432"
# Out:
# '1232420.132432'

# %%
name ="abha"
print("my name is " + name ) ##rarely used
# Out:
# my name is abha

# %%
name ="abjjkbha"
age = 123
print(f"my name is {name} and age is {age} ") ##mostly used ##f---fromatted string method
# Out:
# my name is abjjkbha and age is 123

# %%
name ="abha"
age =789
print("my name is {} and age is {}".format(name,age)) ##old way
# Out:
# my name is abha and age is 789

# %%
a=121
b=1323
c=a+b
f"sum of a= {a} and b={b} is equal to {c}"
# Out:
# 'sum of a= 121 and b=1323 is equal to 1444'

# %% [markdown]
# ## boolean

# %%
x=113
b=678
c=x>b
type(c)
# Out:
# bool
